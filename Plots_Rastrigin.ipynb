# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("1d_Rastrigin_results.csv", 
                 sep='[:, |_]',
                 engine='python', 
                 header=0,
                 usecols=['solution', 'value'])

plt.plot(df.solution, df.value, color='r')
plt.show()

# %%
hist = df.hist()
